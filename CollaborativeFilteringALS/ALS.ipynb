# %%
import pandas as pd
from sklearn import preprocessing

data = pd.read_csv('../data/push_data_500000', sep = '\t', header = None)
data.columns = ['uid', 'zuid', 'open_num', 'gift', 'like_num', 'comment_num', 'share_num', 'view_time', 'watch_time']
print('uid: ', len(set(data['uid'].values)))
print('zuid: ', len(set(data['zuid'].values)))
data.describe()
# Out:
# uid:  306039
# zuid:  59233
#                 uid          zuid       open_num          gift       like_num  \
# count  5.000000e+05  5.000000e+05  500000.000000  5.000000e+05  500000.000000
# mean   6.093745e+09  2.961659e+09       0.040756  8.222116e+01      10.079298
# std    6.844588e+10  1.760767e+09       0.272285  1.631425e+04     651.213035
# min    1.049000e+04  1.203020e+05       0.000000  0.000000e+00       0.000000
# 25%    1.216336e+09  1.706768e+09       0.000000  0.000000e+00       0.000000
# 50%    1.441109e+09  1.986482e+09       0.000000  0.000000e+00       0.000000
# 75%    1.644873e+09  3.980966e+09       0.000000  0.000000e+00       0.000000
# max    1.030021e+12  6.558171e+09      35.000000  1.007232e+07  161995.000000
#
#          comment_num      share_num     view_time     watch_time
# count  500000.000000  500000.000000  5.000000e+05  500000.000000
# mean        0.667702       0.082930 -7.313985e+13     110.455978
# ...

# %% [markdown]
# ### 对数据进行归一化处理，并乘以对应权值，最后得到0-100的分数

# %%
min_max_scaler = preprocessing.MinMaxScaler()
label_encoder = preprocessing.LabelEncoder()
data['uid_index'] = label_encoder.fit_transform(data['uid'].astype(str)).astype(int)
print(label_encoder.transform(['1000000807']))
data['zuid_index'] = label_encoder.fit_transform(data['zuid'].astype(str)).astype(int)
print(label_encoder.transform(['1773807952']))
numerical_columns = ['open_num', 'gift', 'like_num', 'comment_num', 'share_num', 'view_time', 'watch_time']
for column in numerical_columns:
    data[column] = min_max_scaler.fit_transform(data[[column]].values.astype(float))
data['rating'] = data['open_num'] * 20 + data['gift'] * 10 + data['like_num'] * 10 + data['comment_num'] * 10 + data['share_num'] * 10 + data['view_time'] * 20 + data['watch_time'] * 20
data = data[data['rating']>0]
data.describe()
# Out:
# [0]
# [35037]
#                 uid          zuid       open_num           gift  \
# count  4.999990e+05  4.999990e+05  499999.000000  499999.000000
# mean   6.093754e+09  2.961660e+09       0.001164       0.000008
# std    6.844594e+10  1.760769e+09       0.007780       0.001620
# min    1.049000e+04  1.203020e+05       0.000000       0.000000
# 25%    1.216336e+09  1.706768e+09       0.000000       0.000000
# 50%    1.441108e+09  1.986482e+09       0.000000       0.000000
# 75%    1.644873e+09  3.980966e+09       0.000000       0.000000
# max    1.030021e+12  6.558171e+09       1.000000       1.000000
#
#             like_num    comment_num      share_num     view_time  \
# count  499999.000000  499999.000000  499999.000000  4.999990e+05
# mean        0.000062       0.000066       0.000518  9.669448e-01
# std         0.004020       0.003000       0.008960  2.368994e-03
# min         0.000000       0.000000       0.000000  2.955414e-13
# ...

# %%
data.head(5)
# Out:
#           uid        zuid  open_num  gift  like_num  comment_num  share_num  \
# 0    20836475  1773807952       0.0   0.0  0.000006          0.0        0.0
# 1  1000000807  1839116047       0.0   0.0  0.000000          0.0        0.0
# 2  1000000807  2272742990       0.0   0.0  0.000000          0.0        0.0
# 3  1000003300  1000003300       0.0   0.0  0.000000          0.0        0.0
# 4  1000005074  1000005074       0.0   0.0  0.000000          0.0        0.0
#
#    view_time  watch_time uid_index     rating zuid_index
# 0   0.966951         0.0    306038  19.339072      35037
# 1   0.966951         0.0         0  19.339010      36543
# 2   0.966951         0.0         0  19.339010      41540
# 3   0.966951         0.0         1  19.339010          0
# 4   0.966951         0.0         2  19.339010          1

# %%
import h5py
f = h5py.File('../data/movielens_20m.hdf5', 'r')
list(f.keys())
print(f['movie'].value)
print(list(f['movie_user_ratings'].keys()))
print(f['movie_user_ratings']['data'].value)
import pandas as pd
import scipy.sparse as sps

df = pd.DataFrame({'tag1': ['sean', 'udi', 'bogdan'], 'tag2': ['sean', 'udi', 'udi'], 'freq': [1,2,3]})
# tag1 -> rows, tag2 -> columns
df.set_index(['tag1', 'tag2'], inplace=True)

mat = sps.coo_matrix((df.freq, (df.index.labels[0], df.index.labels[1])))
print(mat.todense())
# Out:
# ['' 'Toy Story (1995)' 'Jumanji (1995)' ... 'Rentun Ruusu (2001)' ''
#  'Innocence (2014)']
# ['data', 'indices', 'indptr']
# [4.  5.  4.  ... 2.5 3.  4. ]
# [[0 3]
#  [1 0]
#  [0 2]]

# %%
import implicit
from scipy import sparse
# initialize a model
model = implicit.als.AlternatingLeastSquares(factors = 150, iterations = 100)
# row 为zuid, col为uid
item_user_data = sparse.coo_matrix((data['rating'].values, (data['zuid_index'].values, data['uid_index'].values)))
# train the model on a sparse matrix of item/user/confidence weights
model.fit(item_user_data)
# Out:
#   6%|▌         | 5.5/100 [00:09<03:01,  1.92s/it]/Users/gaochen3/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tqdm/_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)
# 100%|██████████| 100.0/100 [02:37<00:00,  1.38s/it]

# %%
uid_zuid_df = data[['uid', 'zuid', 'zuid_index']]
zuid_index = {}
for index, row in uid_zuid_df.iterrows():
    zuid_index[row['zuid']] = row['zuid_index']
print(len(zuid_index))
uid_zuid_df = uid_zuid_df.groupby(['uid']).apply(lambda tdf : pd.Series(dict([[vv,tdf[vv].unique().tolist()] for vv in tdf if vv not in ['uid']])))
for index, row in uid_zuid_df.iterrows():
    for zuid_index in row['zuid']:
        similar_zuid = model.similar_items(zuid_index)
# Out:
# 59233
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-180-801d304475f5> in <module>()
#       7 for index, row in uid_zuid_df.iterrows():
#       8     for zuid_index in row['zuid']:
# ----> 9         similar_zuid = model.similar_items(zuid_index)
#
# ~/.pyenv/versions/3.5.1/lib/python3.5/site-packages/implicit/recommender_base.py in similar_items(self, itemid, N)
#     164
#     165     def similar_items(self, itemid, N=10):
# --> 166         scores = self.item_factors.dot(self.item_factors[itemid]) / self.item_norms
#     167         best = np.argpartition(scores, -N)[-N:]
#     168         return sorted(zip(best, scores[best] / self.item_norms[itemid]), key=lambda x: -x[1])
#
# IndexError: index 2785513562 is out of bounds for axis 0 with size 59233

# %%
zuid_index = {}
for index in list(set(data['zuid_index'].values)):
    zuid_index[index] = data[data['zuid_index'] == index]['zuid'].values
print(zuid_index)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data[data['zuid'] == '1707254184']
# Out:
#                   uid        zuid  open_num      gift  like_num  comment_num  \
# 535        1000359122  1707254184  0.000000  0.000000  0.000000     0.000000
# 1433       1000959410  1707254184  0.000000  0.000000  0.000000     0.000000
# 2347       1001495353  1707254184  0.028571  0.000000  0.000000     0.000000
# 2842    1001888903805  1707254184  0.028571  0.000000  0.000000     0.000000
# 3055       1001994342  1707254184  0.000000  0.000000  0.000000     0.000000
# 3488       1002327271  1707254184  0.000000  0.000000  0.000000     0.000000
# 3518       1002340292  1707254184  0.000000  0.000000  0.000000     0.000000
# 3794    1002475643849  1707254184  0.028571  0.000000  0.000000     0.000000
# 4126       1002661717  1707254184  0.000000  0.000000  0.000000     0.000000
# 4265       1002741543  1707254184  0.000000  0.000000  0.000000     0.000000
# 4804       1003051201  1707254184  0.000000  0.000000  0.000000     0.000000
# ...

# %%
data[data['zuid_index'] == 45147]
# Out:
#                   uid        zuid  open_num  gift  like_num  comment_num  \
# 115        1000076830  2849479587  0.000000   0.0  0.000000          0.0
# 2292    1001464649949  2849479587  0.000000   0.0  0.000000          0.0
# 3032       1001986404  2849479587  0.000000   0.0  0.000000          0.0
# 3425       1002269030  2849479587  0.000000   0.0  0.000000          0.0
# 7104       1004743194  2849479587  0.000000   0.0  0.000000          0.0
# 7267    1004815229207  2849479587  0.000000   0.0  0.000000          0.0
# 7460    1004926108855  2849479587  0.000000   0.0  0.000000          0.0
# 8729       1005621167  2849479587  0.000000   0.0  0.000000          0.0
# 11854      1007475287  2849479587  0.000000   0.0  0.000000          0.0
# 11924      1007531134  2849479587  0.000000   0.0  0.000000          0.0
# 12216      1007732375  2849479587  0.000000   0.0  0.000012          0.0
# 12686      1008043265  2849479587  0.000000   0.0  0.000000          0.0
# ...
